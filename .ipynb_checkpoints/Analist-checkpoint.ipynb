# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/Hoja.csv')

# %%
df.head(100)
# Out:
#                                            name date_of_event   age
# 0   'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0  \
# 1          Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2              'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3              Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                  Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ..                                          ...           ...   ...
# 95         Muhammad Walid Muhammad 'Abd al-'Aal    2023-05-12  33.0
# 96                   'Ali Hassan Muhammad Ghali    2023-05-11  49.0
# 97                   Ghazi Yusef Mustafa Shihab    2023-05-11  66.0
# 98          Mahmoud Walid Mahmoud 'Abd al-Jawad    2023-05-11  25.0
# 99                                Inga Avramyan    2023-05-11  82.0
#
#     citizenship     event_location event_location_district
# 0   Palestinian     Nur Shams R.C.                 Tulkarm  \
# ...

# %%
df.tail()
# Out:
#                               name date_of_event   age  citizenship
# 11119             Binyamin Herling    2000-10-19  64.0      Israeli  \
# 11120  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0  Palestinian
# 11121             Hillel Lieberman    2000-10-07  36.0      Israeli
# 11122    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0  Palestinian
# 11123            Wichlav Zalsevsky    2000-10-02  24.0      Israeli
#
#       event_location event_location_district event_location_region
# 11119         Nablus                  Nablus             West Bank  \
# 11120     Beit Furik                  Nablus             West Bank
# 11121         Nablus                  Nablus             West Bank
# 11122          Bidya                  Salfit             West Bank
# 11123          Masha                  Salfit             West Bank
#
#       date_of_death gender took_part_in_the_hostilities place_of_residence
# ...

# %%
df.shape
# Out:
# (11124, 16)

# %%
df.columns
# Out:
# Index(['name', 'date_of_event', 'age', 'citizenship', 'event_location',
#        'event_location_district', 'event_location_region', 'date_of_death',
#        'gender', 'took_part_in_the_hostilities', 'place_of_residence',
#        'place_of_residence_district', 'type_of_injury', 'ammunition',
#        'killed_by', 'notes'],
#       dtype='object')

# %%
df = df.rename(columns={'name':'Nombre','date_of_event':'Fecha_Evento','age': 'Edad','citizenship':'Ciudadania','event_location':'Lugar','event_location_district':'Distrito',
                       'event_location_region':'Region','date_of_death':'Fecha_Muerte','gender':'Genero','took_part_in_the_hostilities':'Activista','place_of_residence':'Residencia',
                       'place_of_residence_district':'Distrito_Residencia','type_of_injury':'Tipo_Lesion','ammunition':'Municion',
                       'killed_by':'AsesinadoPor', 'notes':'Obervaciones'})

# %%
df.head()
# Out:
#                                         Nombre Fecha_Evento  edad
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash   2023-09-24  32.0  \
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali   2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan   2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras   2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah   2023-09-19  15.0
#
#     Ciudadania              Lugar Distrito     Region Fecha_Muerte Genero
# 0  Palestinian     Nur Shams R.C.  Tulkarm  West Bank   2023-09-24      M  \
# 1  Palestinian     Nur Shams R.C.  Tulkarm  West Bank   2023-09-24      M
# 2  Palestinian           Kfar Dan    Jenin  West Bank   2023-09-22      M
# 3  Palestinian  'Aqbat Jaber R.C.  Jericho  West Bank   2023-09-20      M
# 4  Palestinian         Jenin R.C.    Jenin  West Bank   2023-09-19      M
#
#   Activista         Residencia Distrito_Residencia Tipo_Lesion
# ...

# %%
df.duplicated().sum()
# Out:
# 7

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# Nombre                    0
# Fecha_Evento              0
# Edad                    122
# Ciudadania                0
# Lugar                     0
# Distrito                  0
# Region                    0
# Fecha_Muerte              0
# Genero                   14
# Activista              1430
# Residencia               61
# Distrito_Residencia      61
# Tipo_Lesion             290
# Municion               5246
# AsesinadoPor              0
# Obervaciones            277
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11117 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Nombre               11117 non-null  object
#  1   Fecha_Evento         11117 non-null  object
#  2   Edad                 10995 non-null  float64
#  3   Ciudadania           11117 non-null  object
#  4   Lugar                11117 non-null  object
#  5   Distrito             11117 non-null  object
#  6   Region               11117 non-null  object
#  7   Fecha_Muerte         11117 non-null  object
#  8   Genero               11103 non-null  object
#  9   Activista            9687 non-null   object
#  10  Residencia           11056 non-null  object
#  11  Distrito_Residencia  11056 non-null  object
#  12  Tipo_Lesion          10827 non-null  object
#  13  Municion             5871 non-null   object
#  14  AsesinadoPor         11117 non-null  object
# ...

# %%
df.describe()
# Out:
#                Edad
# count  10995.000000
# mean      26.745703
# std       13.780548
# min        1.000000
# 25%       19.000000
# 50%       23.000000
# 75%       31.000000
# max      112.000000

# %%
df['Edad'].fillna(df['Edad'].mean(), inplace=True)
df['Genero'].fillna('Unknown', inplace=True)
df['Activista'].fillna('Not Specified', inplace=True)
df['Residencia'].fillna('Unknown', inplace=True)
df['Distrito_Residencia'].fillna('Unknown', inplace=True)
df['Tipo_Lesion'].fillna('Unknown', inplace=True)
df['Municion'].fillna('Unknown', inplace=True)
df['Obervaciones'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# name                            0
# date_of_event                   0
# age                             0
# citizenship                     0
# event_location                  0
# event_location_district         0
# event_location_region           0
# date_of_death                   0
# gender                          0
# took_part_in_the_hostilities    0
# place_of_residence              0
# place_of_residence_district     0
# type_of_injury                  0
# ammunition                      0
# killed_by                       0
# notes                           0
# dtype: int64

# %%
df['Fecha_Evento'] = pd.to_datetime(df['Fecha_Evento'])
df['Fecha_Muerte'] = pd.to_datetime(df['Fecha_Muerte'])

# %%
df.nunique()
# Out:
# Nombre                 11083
# Fecha_Evento            2405
# Edad                      96
# Ciudadania                 4
# Lugar                    494
# Distrito                  20
# Region                     3
# Fecha_Muerte            2593
# Genero                     3
# Activista                  6
# Residencia               581
# Distrito_Residencia       21
# Tipo_Lesion               14
# Municion                  22
# AsesinadoPor               3
# Obervaciones            6745
# dtype: int64
